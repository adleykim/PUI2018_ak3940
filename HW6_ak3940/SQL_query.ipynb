# %% [markdown]
# # SQL CARTO QUERY FUNCTION
# # written for PUI2016_Python2

# %% [markdown]
# ##### This notebook is set up to link as a default to the fb55 account.  To turn in the homework use the citibike dataset - check that you are able to read in about 40k rows

# %%
SQL_SOURCE = 'https://fb55.carto.com/api/v2/sql?q='

import urllib2
import urllib
import StringIO
import ast
import pandas as pd

def queryCartoDB(query, format='CSV', source=SQL_SOURCE):
    '''queries carto datasets from a given carto account
    Arguments: 
    query - string: a valid sql query string
    format - outlut format  OPTIONAL (default CSV)
    source - a valid sql api endpoint OPTIONAL (default carto fb55 account)
    Returns:
    the return of the sql query AS A STRING
    NOTES:
    designed for the carto API, tested only with CSV return format'''
    
    data = urllib.urlencode({'format': format, 'q': query})
    try:
        response = urllib2.urlopen(source, data)
    except urllib2.HTTPError, e:
        raise ValueError('\n'.join(ast.literal_eval(e.readline())['error']))
    except Exception:
        raise
    return response.read()

# %%
test = '''
SELECT *
FROM citibike_short
'''

# %%
pd.read_csv(StringIO.StringIO(queryCartoDB(test)), sep=',')
# Out:
#      the_geom  start_station_longitude  the_geom_webmercator  tripduration  \
# 0         NaN               -73.994811                   NaN           801
# 1         NaN               -73.985649                   NaN           245
# 2         NaN               -73.990093                   NaN           379
# 3         NaN               -73.973715                   NaN          2474
# 4         NaN               -74.004704                   NaN           818
# 5         NaN               -73.986317                   NaN           544
# 6         NaN               -73.953820                   NaN           717
# 7         NaN               -73.977225                   NaN          1306
# 8         NaN               -73.989780                   NaN           913
# 9         NaN               -73.994046                   NaN           759
# 10        NaN               -74.002638                   NaN           585
# ...

# %% [markdown]
# # extra credit: make the function python 2 and 3 compatible so that it works on the  PUI2016_Python3 kernel

# %% [markdown]
# # Task 1

# %%
query = '''
SELECT * FROM fb55.citibike
WHERE tripduration <= 10800
ORDER BY start_station_id, tripduration
'''

pd.read_csv(StringIO.StringIO(queryCartoDB(query)), sep=',')

# %%
query = '''
SELECT * FROM fb55.citibike
WHERE tripduration <= 10800
ORDER BY start_station_id, tripduration
LIMIT 10
'''

pd.read_csv(StringIO.StringIO(queryCartoDB(query)), sep=',')
# Out:
#    the_geom start_station_name  the_geom_webmercator  field_1  \
# 0       NaN   W 52 St & 11 Ave                   NaN     9059
# 1       NaN   W 52 St & 11 Ave                   NaN    40772
# 2       NaN   W 52 St & 11 Ave                   NaN    40770
# 3       NaN   W 52 St & 11 Ave                   NaN    22002
# 4       NaN   W 52 St & 11 Ave                   NaN    43107
# 5       NaN   W 52 St & 11 Ave                   NaN    32603
# 6       NaN   W 52 St & 11 Ave                   NaN    16015
# 7       NaN   W 52 St & 11 Ave                   NaN    41366
# 8       NaN   W 52 St & 11 Ave                   NaN    42084
# 9       NaN   W 52 St & 11 Ave                   NaN     2348
#
#    start_station_longitude  tripduration               starttime  \
# 0               -73.993929           107  2015-02-03 10:10:00+00
# 1               -73.993929           189  2015-02-07 10:40:00+00
# 2               -73.993929           229  2015-02-07 10:40:00+00
# ...

# %%
query = '''
SELECT * FROM fb55.citibike
WHERE tripduration <= 10800
ORDER BY start_station_id DESC, tripduration DESC
LIMIT 10
'''

pd.read_csv(StringIO.StringIO(queryCartoDB(query)), sep=',')
# Out:
#    the_geom          start_station_name  the_geom_webmercator  field_1  \
# 0       NaN  South End Ave & Liberty St                   NaN     1576
# 1       NaN  South End Ave & Liberty St                   NaN     8891
# 2       NaN  South End Ave & Liberty St                   NaN    23568
# 3       NaN  South End Ave & Liberty St                   NaN    10232
# 4       NaN  South End Ave & Liberty St                   NaN    27243
# 5       NaN  South End Ave & Liberty St                   NaN     6846
# 6       NaN  South End Ave & Liberty St                   NaN    44708
# 7       NaN  South End Ave & Liberty St                   NaN    11648
# 8       NaN  South End Ave & Liberty St                   NaN     1297
# 9       NaN  South End Ave & Liberty St                   NaN    17637
#
#    start_station_longitude  tripduration               starttime  \
# 0               -74.015756          7225  2015-02-01 11:46:00+00
# ...

# %%
query = '''
SELECT DISTINCT start_station_id FROM fb55.citibike
WHERE tripduration <= 10800
'''

pd.read_csv(StringIO.StringIO(queryCartoDB(query)), sep=',')
# Out:
#      start_station_id  Unnamed: 1
# 0                 120         NaN
# 1                 285         NaN
# 2                 251         NaN
# 3                 195         NaN
# 4                 453         NaN
# 5                 144         NaN
# 6                 266         NaN
# 7                 263         NaN
# 8                 216         NaN
# 9                 328         NaN
# 10                353         NaN
# 11                212         NaN
# 12                383         NaN
# 13                538         NaN
# 14                217         NaN
# 15                300         NaN
# 16                456         NaN
# 17                128         NaN
# 18                223         NaN
# 19                244         NaN
# 20                494         NaN
# 21                403         NaN
# 22                260         NaN
# 23                445         NaN
# 24                411         NaN
# 25                377         NaN
# ...

# %%
query = '''
SELECT COUNT(*) FROM fb55.citibike
WHERE tripduration <= 10800
'''

pd.read_csv(StringIO.StringIO(queryCartoDB(query)), sep=',')
# Out:
#    count  Unnamed: 1
# 0  46151         NaN

# %%
query = '''
SELECT AVG(tripduration), MIN(tripduration), MAX(tripduration) FROM fb55.citibike
WHERE tripduration <= 10800
'''

pd.read_csv(StringIO.StringIO(queryCartoDB(query)), sep=',')
# Out:
#           avg  min    max
# 0  652.028342   60  10757

# %% [markdown]
# # Task 2

# %%
query = '''
SELECT * FROM fb55.citibike
WHERE DATE(starttime) = '2015-02-02'
'''

pd.read_csv(StringIO.StringIO(queryCartoDB(query)), sep=',')
# Out:
#       the_geom           start_station_name  the_geom_webmercator  field_1  \
# 0          NaN              5 Ave & E 29 St                   NaN     7433
# 1          NaN         Allen St & Hester St                   NaN     7779
# 2          NaN            E 5 St & Avenue C                   NaN       11
# 3          NaN              9 Ave & W 16 St                   NaN      627
# 4          NaN              9 Ave & W 16 St                   NaN      991
# 5          NaN              W 33 St & 7 Ave                   NaN     1037
# 6          NaN              W 27 St & 7 Ave                   NaN     6510
# 7          NaN              E 11 St & 1 Ave                   NaN     6511
# 8          NaN         Peck Slip & Front St                   NaN     6512
# 9          NaN              E 16 St & 5 Ave                   NaN     6513
# 10         NaN              W 41 St & 8 Ave                   NaN     6514
# ...

# %%
query = '''
SELECT AVG(tripduration) FROM fb55.citibike
WHERE EXTRACT(dow FROM starttime::date) IN (5,6)
'''

pd.read_csv(StringIO.StringIO(queryCartoDB(query)), sep=',')
# Out:
#           avg  Unnamed: 1
# 0  658.922681         NaN

# %%
query = '''
SELECT AVG(tripduration) FROM fb55.citibike
WHERE EXTRACT(dow FROM starttime::date) IN (2,3,4,5,6)
'''

pd.read_csv(StringIO.StringIO(queryCartoDB(query)), sep=',')
# Out:
#           avg  Unnamed: 1
# 0  672.875822         NaN

# %% [markdown]
# # Task 3

# %%
query = '''
SELECT DISTINCT start_station_name FROM fb55.citibike
'''

pd.read_csv(StringIO.StringIO(queryCartoDB(query)), sep=',')
# Out:
#                 start_station_name  Unnamed: 1
# 0             E 30 St & Park Ave S         NaN
# 1          Pearl St & Anchorage Pl         NaN
# 2                  W 56 St & 6 Ave         NaN
# 3                   West Thames St         NaN
# 4          Bank St & Washington St         NaN
# 5                  8 Ave & W 52 St         NaN
# 6               E 11 St & Broadway         NaN
# 7         DeKalb Ave & Skillman St         NaN
# 8    Atlantic Ave & Fort Greene Pl         NaN
# 9                Avenue D & E 8 St         NaN
# 10            S 3 St & Bedford Ave         NaN
# 11          W Broadway & Spring St         NaN
# 12                 2 Ave & E 31 St         NaN
# 13                 E 33 St & 5 Ave         NaN
# 14        MacDougal St & Prince St         NaN
# 15    Clermont Ave & Lafayette Ave         NaN
# 16          Barclay St & Church St         NaN
# 17          Forsyth St & Broome St         NaN
# 18                 W 13 St & 6 Ave         NaN
# ...

# %%
query = '''
SELECT start_station_name, COUNT(*) FROM fb55.citibike
GROUP BY start_station_name
'''

pd.read_csv(StringIO.StringIO(queryCartoDB(query)), sep=',')
# Out:
#                 start_station_name  count
# 0             E 30 St & Park Ave S    227
# 1          Pearl St & Anchorage Pl     54
# 2                  W 56 St & 6 Ave    164
# 3                   West Thames St    107
# 4          Bank St & Washington St    125
# 5                  8 Ave & W 52 St    133
# 6               E 11 St & Broadway    115
# 7         DeKalb Ave & Skillman St     10
# 8    Atlantic Ave & Fort Greene Pl     36
# 9                Avenue D & E 8 St     38
# 10            S 3 St & Bedford Ave     13
# 11          W Broadway & Spring St    159
# 12                 2 Ave & E 31 St    302
# 13                 E 33 St & 5 Ave    213
# 14        MacDougal St & Prince St    247
# 15    Clermont Ave & Lafayette Ave     25
# 16          Barclay St & Church St    244
# 17          Forsyth St & Broome St    212
# 18                 W 13 St & 6 Ave    257
# 19                 W 17 St & 8 Ave    288
# 20              E 20 St & Park Ave    218
# ...

# %%
query = '''
SELECT start_station_name, COUNT(*) FROM (SELECT start_station_name, start_station_latitude, start_station_longitude
FROM fb55.citibike
WHERE (
          acos(sin(start_station_latitude * 0.0175) * sin(40.7577* 0.0175) 
               + cos(start_station_latitude * 0.0175) * cos(40.7577* 0.0175) *    
                 cos((-73.9857 * 0.0175) - (start_station_longitude * 0.0175))
              ) * 6371000 <= 500
      )) AS timesquare
      
GROUP BY start_station_name
'''

pd.read_csv(StringIO.StringIO(queryCartoDB(query)), sep=',')
# Out:
#    start_station_name  count
# 0     W 45 St & 8 Ave    141
# 1     W 42 St & 8 Ave    221
# 2  Broadway & W 49 St    213
# 3     W 43 St & 6 Ave    112
# 4     W 41 St & 8 Ave    507
# 5     W 45 St & 6 Ave    141
# 6  Broadway & W 41 St    251

# %% [markdown]
# # Task 4

# %%
query = '''
SELECT start_station_name, MAX(avg) FROM (
SELECT start_station_name, AVG(tripduration) FROM (
SELECT * FROM fb55.citibike
WHERE (
          acos(sin(start_station_latitude * 0.0175) * sin(40.7577* 0.0175) 
               + cos(start_station_latitude * 0.0175) * cos(40.7577* 0.0175) *    
                 cos((-73.9857 * 0.0175) - (start_station_longitude * 0.0175))
              ) * 6371000 <= 500
      )) AS timesquare
GROUP BY start_station_name) AS avgtd
GROUP BY start_station_name
ORDER BY max DESC
LIMIT 1
'''

pd.read_csv(StringIO.StringIO(queryCartoDB(query)), sep=',')
# Out:
#   start_station_name         max
# 0    W 45 St & 8 Ave  738.815603
